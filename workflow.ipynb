# %%
import plotly.graph_objects as go

from collections import Counter

import networkx as nx

# %%
keywords = [['Research Article',
  'Open Access',
  'Graphene oxide (GO)',
  "Hummer's method",
  'Oxidation',
  'XRD',
  'FT-IR spectrum',
  'SEM',
  'Nanoscience',
  'Nanotechnology',
  'Synthesis',
  'Characterization',
  'Nanomaterials',
  'Carbon',
  'Allotropes of carbon',
  'Scalability',
  'Electrical insulator',
  'Sp2 bonding networks',
  'Mass production',
  'Water purification',
  'Super capacitors',
  'Antibacterial activity',
  'Solar cells',
  'Coatings',
  'Functionalization',
  'Hygroscopicity',
  'Dispersibility',
  'Toxicity',
  'Chemically modified graphenes (CMGs)',
  'Methods and Materials',
  'Epoxide',
  'Hydroxyl groups'],
 ['Nano Res.',
  'Solvothermal synthesis',
  'Graphene–CdS',
  'Graphene–ZnS',
  'Quantum dot nanocomposites',
  'Photovoltaic properties',
  'Ping Wang',
  'Tengfei Jiang',
  'Chengzhou Zhu',
  'Yueming Zhai',
  'Dejun Wang',
  'Shaojun Dong',
  'State Key Laboratory of Electroanalytical Chemistry',
  'Changchun Institute of Applied Chemistry',
  'Chinese Academy of Sciences',
  'Jilin University',
  'Abstract',
  'Optoelectronic properties',
  'Graphene oxide',
  'Photoluminescence',
  'Transient photovoltage',
  'Charge transfer',
  'Introduction',
  'Carbon nanotubes',
  'Li et al.',
  'Semiconductor QDs',
  'CdS',
  'ZnS'],
 ['Graphene nanoplatelet',
  'Graphene oxide',
  'Face mask materials',
  'SARS-CoV-2',
  'Inhibits infectivity',
  'Functionalization',
  'Trapped particles',
  'Cotton',
  'Polyurethane',
  'Nanoparticles',
  'Infection inhibition',
  'Fabrics',
  'Bacteria',
  'Biocompatible',
  'iScience'],
 ['Professor Kumar Varoon Agrawal',
  'Institute of Chemical Sciences & Engineering (ISIC)',
  'École Polytechnique Fédérale de Lausanne (EPFL)',
  'Switzerland',
  'High-permeance polymer-functionalized single-layer graphene membranes',
  'Postcombustion carbon capture',
  'Energy-efficiency',
  'Capture penalty',
  'Nanoporous single-layer graphene',
  'CO2-selective polymer layers',
  'CO2/N2 selectivity',
  'Critical separations',
  'Tao Liu',
  'Xinhui Lu',
  'Xugang Guo',
  'He Yan',
  'Monothiophene unit',
  'Non-fullerene solar cells',
  'Efficiency'],
 ['1. Ballistic tracks',
  '2. Graphene nanoribbons',
  '3. Epitaxially grown',
  '4. Silicon carbide',
  '5. Sidewall ribbons',
  '6. Single-channel ballistic transport',
  '7. Mean free paths',
  '8. Two-point probe measurements',
  '9. Transport modes',
  '10. Conductance plateaus',
  '11. Edge magnetism',
  '12. Asymmetric terminations',
  '13. SiC structure morphology',
  '14. Graphene-based devices',
  '15. Quantum information device concepts',
  '16. Institut für Physik',
  '17. Technische Universität Chemnitz',
  '18. Catalan Institute of Nanoscience and Nanotechnology (ICN2)',
  '19. Barcelona Institute of Science and Technology',
  '20. Campus UAB',
  '21. Bellaterra',
  '22. Universitat Autònoma de Barcelona',
  '23. School of Physics',
  '24. Trinity College Dublin',
  '25. Physics of Interfaces and Nanomaterials',
  '26. MESA+ Institute for Nanotechnology',
  '27. University of Twente',
  '28. Hannover',
  '29. ICREA',
  '30. Institució Catalana de Recerca i Estudis Avançats',
  '31. Center for Nanostructured Graphene (CNG)',
  '32. Technical University of Denmark',
  '33. MAX IV Laboratory',
  '34. Lund University',
  '35. Nature Communications'],
 ['Applied Optics',
  'Copyright',
  'Authors',
  'American Association for the Advancement of Science',
  'U.S. Government Works',
  'Creative Commons Attribution-NonCommercial License 4.0',
  'Electrical access',
  'Critical coupling',
  'Circularly polarized waves',
  'Graphene chiral metamaterials',
  'Polarization control',
  'Terahertz waves',
  'Chiral materials',
  'Chiral metamaterials',
  'Circular polarization states',
  'Optical activity',
  'Quartz crystal',
  'Chiral structures',
  'Terahertz frequencies',
  'Electrical approach',
  'Graphene',
  'Controlled polarization state',
  'Gate voltage',
  'Density of states',
  'Intra-band transitions',
  'Graphene-based metamaterials',
  'Circular dichroism',
  'Optical conductivity',
  'Radiation loss parameters',
  'Linearly polarized waves',
  'Selective control',
  'Conjugated double Z metamaterials',
  'Gate-controlled CD and OA',
  'Change in optical conductivity',
  'Radiation loss',
  'P-doped graphene',
  'Wet transfer method',
  'Raman spectroscopy',
  'Chemical vapor deposition (CVD)',
  'Conductivity control'],
 ['Scientific Reports',
  'Digital Biosensing',
  'Foundry-Fabricated Graphene sensors',
  'Biological testing',
  'ELISA',
  'Lateral flow assays',
  'Device physics',
  'Nanotechnology',
  'Electrical approaches',
  'Computational resources',
  'Internet of biology',
  'Internet of things',
  'Field effect biosensing',
  'Bioelectronic devices',
  'Industrial manufacturing',
  'Nanoelectronic sensors',
  'Biotech engineers',
  'Medical testing',
  'Software tools',
  'Quality healthcare',
  'Point-of-care tools',
  'Central lab',
  'Colorimetric assays',
  'PCR based assays',
  'Label-free measurement tools',
  'Field-effect sensors',
  'Single sensor manufacturing chain',
  'Lower cost',
  'Commercial production',
  'Graphene-enabled Field Effect Biosensing (FEB)',
  'Ion Sensitive Field Effect Transistor (ISFET)',
  'Semiconductor behavior',
  'Chemical stability',
  'Sensor surface',
  'Salt water',
  'Silicon oxide layers',
  'Graphene',
  'Carbon nanotubes',
  'Molybdenum disulfide',
  'Electronic interfaces',
  'Biomedical use',
  'Fabrication techniques',
  'Cardea Bio inc.',
  'San Diego, CA, USA'],
 ['HAL',
  'open access',
  'archive',
  'scientific research documents',
  'teaching and research institutions',
  'France',
  'abroad',
  'public research centers',
  'private research centers',
  'classification framework',
  'graphene-based materials',
  'Peter Wick',
  'Anna E. Louw-Gaume',
  'Melanie Kucki',
  'Harald F. Krug',
  'Kostas Kostarelos',
  'Bengt Fadeel',
  'Kenneth A. Dawson',
  'Anna Salvati',
  'Ester Vázquez',
  'Laura Ballerini',
  'Angewandte Chemie International Edition',
  '7714-7718'],
 ['nanogra phenes',
  'synthetic tailoring',
  'graphene nanostructures',
  'zigzag-edged topologies',
  'bottom-up synthesis',
  'doping',
  'graphene nanoribbons',
  'magnetism'],
 ['graphene-based materials',
  'environmental protection',
  'detection',
  'adsorbent',
  'sensor',
  'heavy metal ions',
  'organic pollutants']]

# %%
papers = ['arthigSimpleApproachStepwise2015.pdf',
 'wangOnestepSolvothermalSynthesis2010.pdf',
 'demaioGrapheneNanoplateletGraphene2021.pdf',
 'heHighpermeancePolymerfunctionalizedSinglelayer2019.pdf',
 'aprojanzBallisticTracksGraphene2018.pdf',
 'kimElectricalAccessCritical2017.pdf',
 'goldsmithDigitalBiosensingFoundryFabricated2019.pdf',
 'wickClassificationFrameworkGrapheneBased2014.pdf',
 'liuSyntheticTailoringGraphene2020.pdf',
 'luApplicationsGraphenebasedMaterials2013.pdf']

# %%
edges = []
for i in range(len(papers)):
    for j in range(len(keywords[i])):
        edges.append([papers[i], keywords[i][j]])

# Flatten the list of lists
flattened = [item for sublist in edges for item in sublist]

# Count the occurrences of each element in the flattened list
counts = Counter(flattened)

# Get all elements that appear more than once
duplicates = [element for element in counts if counts[element] > 1]

# Filter the list of paired lists to only include items that appear more than once
edges = [edge for edge in edges if edge[0] in duplicates and edge[1] in duplicates]

# %%
# Create an empty graph
G = nx.Graph()

# Add nodes to the graph
for sublist in edges:
    for node in sublist:
        G.add_node(node)

# Add edges to the graph
for sublist in edges:
    G.add_edge(sublist[0], sublist[1])

# give a random position to each node
pos = nx.random_layout(G)
for node in G.nodes():
    # print(node)
    # print(pos[nod/e])
    G.nodes[node]['pos'] = pos[node].tolist()

# %%
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['pos']
    x1, y1 = G.nodes[edge[1]]['pos']
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

node_x = []
node_y = []
for node in G.nodes():
    x, y = G.nodes[node]['pos']
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    text=list(G.nodes()),
    hoverinfo='text',
    marker=dict(
        showscale=True,
        # colorscale options
        #'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        #'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        #'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line_width=2))

# %%
node_adjacencies = []
node_text = []
for node, adjacencies in enumerate(G.adjacency()):
    node_adjacencies.append(len(adjacencies[1]))
    # node_text.append('# of connections: '+str(len(adjacencies[1])))
    node_text.append(list(G.nodes)[node])

node_trace.marker.color = node_adjacencies
node_trace.text = node_text

# %%
fig = go.Figure(data=[edge_trace, node_trace],
             layout=go.Layout(
                title='<br>Network graph made with Python',
                titlefont_size=16,
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                )
fig.show()
